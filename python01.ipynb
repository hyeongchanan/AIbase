# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeongchanan/AIbase/blob/main/python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
print(a)

# %%
m = int(input("시간을 입력하세요"))
h = m // 60
m = m % 60
print(h,"시간",m,"분")
# Out:
# 시간을 입력하세요20000
# 333 시간 20 분

# %%
x= 3
y = 3.5
j=[1,4,10,35,8]

# %%
sum(j)
# Out:
# 58

# %%
b =[[1,2,3,4],[10,20,30,40]]
print(b)
# Out:
# [[1, 2, 3, 4], [10, 20, 30, 40]]

# %%
import pandas as pd
df = pd.read_excel('통합 문서1.xlsx',header=None)
print(df)
df
# Out:
#     0   1   2    3     4
# 0 NaN NaN NaN  NaN   NaN
# 1 NaN NaN NaN  NaN   NaN
# 2 NaN NaN NaN  NaN   NaN
# 3 NaN NaN NaN  1.0  10.0
# 4 NaN NaN NaN  2.0  20.0
# 5 NaN NaN NaN  3.0  30.0
#     0   1   2    3     4
# 0 NaN NaN NaN  NaN   NaN
# 1 NaN NaN NaN  NaN   NaN
# 2 NaN NaN NaN  NaN   NaN
# 3 NaN NaN NaN  1.0  10.0
# 4 NaN NaN NaN  2.0  20.0
# 5 NaN NaN NaN  3.0  30.0

# %%
import pandas as pd
df = pd.read_csv('sss.csv',header=None)
print(df)
df
# Out:
#    0   1
# 0  1  10
# 1  2  20
# 2  3  30
#    0   1
# 0  1  10
# 1  2  20
# 2  3  30

# %%
import pandas as pd
df = pd.read_csv('sss.csv')
df.he
df['he']
# Out:
# 0    1
# 1    2
# 2    3
# Name: he, dtype: int64

# %%
df['he']
# Out:
# 0    1
# 1    2
# 2    3
# Name: he, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   he      3 non-null      int64
#  1   ne      3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
sd = pd.read_csv('Student_Marks.csv')
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
sd.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %% [markdown]
# 5개의 데이터

# %% [markdown]
# 비어있는 데이터 : 결측치

# %%
df.describe()
# Out:
#         he    ne
# count  3.0   3.0
# mean   2.0  20.0
# std    1.0  10.0
# min    1.0  10.0
# 25%    1.5  15.0
# 50%    2.0  20.0
# 75%    2.5  25.0
# max    3.0  30.0

# %% [markdown]
# 개수,중앙값,표준편차,최저값,4분위수,최대값

# %%
sd.isnull()
# Out:
#     number_courses  time_study  Marks
# 0            False       False  False
# 1            False       False  False
# 2            False       False  False
# 3            False       False  False
# 4            False       False  False
# ..             ...         ...    ...
# 95           False       False  False
# 96           False       False  False
# 97           False       False  False
# 98           False       False  False
# 99           False       False  False
#
# [100 rows x 3 columns]

# %%
sd.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64
